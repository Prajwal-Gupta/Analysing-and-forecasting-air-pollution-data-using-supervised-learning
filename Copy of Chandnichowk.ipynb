# %%
#Importing Libraries
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Importing dataset
df = pd.read_csv('/content/drive/MyDrive/MiniProject/Chandinichowk_data.csv')

# %%
# printing the dataset
df
# Out:
#            Day        Date      Time  PM2.5   PM10   NO2   NH3   SO2    CO  \
# 0       Monday  01-08-2022  00:00:00   57.0   70.0  84.0  12.0   6.0  80.0
# 1       Monday  01-08-2022  01:00:00    0.0   20.0  58.0  12.0  26.0  90.0
# 2       Monday  01-08-2022  02:00:00   18.0   46.0  62.0  14.0  20.0  72.0
# 3       Monday  01-08-2022  03:00:00   72.0  140.0   NaN   NaN   NaN   NaN
# 4       Monday  01-08-2022  04:00:00   55.0   86.0  57.0   NaN   2.0  80.0
# ..         ...         ...       ...    ...    ...   ...   ...   ...   ...
# 739  Wednesday  08-31-2022  19:00:00   68.0  119.0  49.0  10.0  14.0  35.0
# 740  Wednesday  08-31-2022  20:00:00   47.0  105.0  52.0  10.0  14.0  38.0
# 741  Wednesday  08-31-2022  21:00:00   32.0   78.0  65.0  10.0  14.0  43.0
# 742  Wednesday  08-31-2022  22:00:00    NaN   46.0  67.0  11.0  15.0  57.0
# 743  Wednesday  08-31-2022  23:00:00   45.0   88.0  66.0  11.0  16.0  63.0
#
#      OZONE    AQI
# 0     48.0  102.0
# 1     38.0  105.0
# 2     31.0  104.0
# 3      NaN   99.0
# 4     51.0   99.0
# ..     ...    ...
# 739   77.0   97.0
# 740   54.0   97.0
# 741   21.0   99.0
# 742   12.0   98.0
# 743   11.0   98.0
#
# [744 rows x 11 columns]

# %%
# Finding the if columns have NA values or not
pd.isnull(df).sum()
# Out:
# Day        0
# Date       0
# Time       0
# PM2.5    156
# PM10      89
# NO2       73
# NH3       92
# SO2      111
# CO       107
# OZONE    135
# AQI       72
# dtype: int64

# %%
# Dropping 'NH3' column as most of it's values are null
# df1 = df.drop(['NH3'], axis=1)

# %%
df1 = df.copy()

# %%
df1
# Out:
#            Day        Date      Time  PM2.5   PM10   NO2   NH3   SO2    CO  \
# 0       Monday  01-08-2022  00:00:00   57.0   70.0  84.0  12.0   6.0  80.0
# 1       Monday  01-08-2022  01:00:00    0.0   20.0  58.0  12.0  26.0  90.0
# 2       Monday  01-08-2022  02:00:00   18.0   46.0  62.0  14.0  20.0  72.0
# 3       Monday  01-08-2022  03:00:00   72.0  140.0   NaN   NaN   NaN   NaN
# 4       Monday  01-08-2022  04:00:00   55.0   86.0  57.0   NaN   2.0  80.0
# ..         ...         ...       ...    ...    ...   ...   ...   ...   ...
# 739  Wednesday  08-31-2022  19:00:00   68.0  119.0  49.0  10.0  14.0  35.0
# 740  Wednesday  08-31-2022  20:00:00   47.0  105.0  52.0  10.0  14.0  38.0
# 741  Wednesday  08-31-2022  21:00:00   32.0   78.0  65.0  10.0  14.0  43.0
# 742  Wednesday  08-31-2022  22:00:00    NaN   46.0  67.0  11.0  15.0  57.0
# 743  Wednesday  08-31-2022  23:00:00   45.0   88.0  66.0  11.0  16.0  63.0
#
#      OZONE    AQI
# 0     48.0  102.0
# 1     38.0  105.0
# 2     31.0  104.0
# 3      NaN   99.0
# 4     51.0   99.0
# ..     ...    ...
# 739   77.0   97.0
# 740   54.0   97.0
# 741   21.0   99.0
# 742   12.0   98.0
# 743   11.0   98.0
#
# [744 rows x 11 columns]

# %%
# checking for null values
pd.isnull(df1).sum()
# Out:
# Day        0
# Date       0
# Time       0
# PM2.5    156
# PM10      89
# NO2       73
# NH3       92
# SO2      111
# CO       107
# OZONE    135
# AQI       72
# dtype: int64

# %%
# printing rows having any null values
df1[df1.isnull().any(axis=1)]
# Out:
#            Day        Date      Time  PM2.5   PM10   NO2   NH3   SO2    CO  \
# 3       Monday  01-08-2022  03:00:00   72.0  140.0   NaN   NaN   NaN   NaN
# 4       Monday  01-08-2022  04:00:00   55.0   86.0  57.0   NaN   2.0  80.0
# 29     Tuesday  02-08-2022  05:00:00   30.0   84.0   NaN   NaN   NaN   NaN
# 49   Wednesday  03-08-2022  01:00:00    NaN   22.0  52.0   3.0   NaN   NaN
# 50   Wednesday  03-08-2022  02:00:00    NaN   30.0  52.0   3.0  36.0  15.0
# ..         ...         ...       ...    ...    ...   ...   ...   ...   ...
# 701    Tuesday  08-30-2022  05:00:00    NaN   25.0  57.0  11.0  12.0  32.0
# 722  Wednesday  08-31-2022  02:00:00   83.0  107.0  51.0  10.0  16.0  30.0
# 723  Wednesday  08-31-2022  03:00:00   50.0   91.0  47.0  10.0   NaN   NaN
# 728  Wednesday  08-31-2022  08:00:00    NaN    NaN   NaN   NaN   NaN   NaN
# 742  Wednesday  08-31-2022  22:00:00    NaN   46.0  67.0  11.0  15.0  57.0
#
#      OZONE    AQI
# 3      NaN   99.0
# 4     51.0   99.0
# 29     NaN   52.0
# 49     5.0   50.0
# 50     9.0   51.0
# ..     ...    ...
# 701   11.0  103.0
# 722    NaN   95.0
# 723   12.0   96.0
# 728    NaN  100.0
# 742   12.0   98.0
#
# [313 rows x 11 columns]

# %%
# filling the null values
df2 = df1.interpolate(method ='linear', limit_direction ='forward')

# %%
df2
# Out:
#            Day        Date      Time  PM2.5   PM10   NO2        NH3   SO2  \
# 0       Monday  01-08-2022  00:00:00   57.0   70.0  84.0  12.000000   6.0
# 1       Monday  01-08-2022  01:00:00    0.0   20.0  58.0  12.000000  26.0
# 2       Monday  01-08-2022  02:00:00   18.0   46.0  62.0  14.000000  20.0
# 3       Monday  01-08-2022  03:00:00   72.0  140.0  59.5  13.666667  11.0
# 4       Monday  01-08-2022  04:00:00   55.0   86.0  57.0  13.333333   2.0
# ..         ...         ...       ...    ...    ...   ...        ...   ...
# 739  Wednesday  08-31-2022  19:00:00   68.0  119.0  49.0  10.000000  14.0
# 740  Wednesday  08-31-2022  20:00:00   47.0  105.0  52.0  10.000000  14.0
# 741  Wednesday  08-31-2022  21:00:00   32.0   78.0  65.0  10.000000  14.0
# 742  Wednesday  08-31-2022  22:00:00   38.5   46.0  67.0  11.000000  15.0
# 743  Wednesday  08-31-2022  23:00:00   45.0   88.0  66.0  11.000000  16.0
#
#        CO  OZONE    AQI
# 0    80.0   48.0  102.0
# 1    90.0   38.0  105.0
# 2    72.0   31.0  104.0
# 3    76.0   41.0   99.0
# 4    80.0   51.0   99.0
# ..    ...    ...    ...
# 739  35.0   77.0   97.0
# 740  38.0   54.0   97.0
# 741  43.0   21.0   99.0
# 742  57.0   12.0   98.0
# 743  63.0   11.0   98.0
#
# [744 rows x 11 columns]

# %%
# checking for null values
pd.isnull(df2).sum()
# Out:
# Day      0
# Date     0
# Time     0
# PM2.5    0
# PM10     0
# NO2      0
# NH3      0
# SO2      0
# CO       0
# OZONE    0
# AQI      0
# dtype: int64

# %%
df2.to_csv(r'/content/drive/MyDrive/MiniProject/chandnichowk_model.csv', index = 'False')

# %%
# finding mean of each column in the dataset having null values
df1.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7dbb03757b07> in <module>
#       1 # finding mean of each column in the dataset having null values
# ----> 2 df1.mean()
#
# NameError: name 'df1' is not defined

# %%
# finding mean of each column not having null values
df2.mean()

# %% [markdown]
# As observed, the mean of each column has changed after filling the NA values, but not by a very significant amount

# %%
corr = df2.corr()
print(corr)
# Out:
#           PM2.5      PM10       NO2       NH3       SO2        CO     OZONE  \
# PM2.5  1.000000  0.550349 -0.017838  0.083847  0.169380  0.143372  0.192097
# PM10   0.550349  1.000000  0.217706  0.212407  0.162234  0.105717  0.298153
# NO2   -0.017838  0.217706  1.000000 -0.054041  0.092754  0.092366  0.239369
# NH3    0.083847  0.212407 -0.054041  1.000000  0.104789  0.158755  0.124965
# SO2    0.169380  0.162234  0.092754  0.104789  1.000000  0.021038 -0.075434
# CO     0.143372  0.105717  0.092366  0.158755  0.021038  1.000000 -0.032954
# OZONE  0.192097  0.298153  0.239369  0.124965 -0.075434 -0.032954  1.000000
# AQI    0.251273  0.549111  0.428879  0.376483  0.075306  0.145993  0.325284
#
#             AQI
# PM2.5  0.251273
# PM10   0.549111
# NO2    0.428879
# NH3    0.376483
# SO2    0.075306
# CO     0.145993
# OZONE  0.325284
# AQI    1.000000

# %%
fig, ax = plt.subplots(figsize=(10,10)) 
corr_plot = sns.heatmap(corr, annot = True, ax=ax)
print(corr_plot)
# Out:
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
df2.boxplot()

# %% [markdown]
# ## Hourly data

# %% [markdown]
# Working on hourly data and plotting graphs for each column

# %%
# function to plot each column
def plot_points(col_name):
  fig = plt.figure(figsize =(30, 10))
  for i in range(0,len(df2), 24):
      plt.plot(df2.loc[range(i+0,i+24), col_name])
  print('The hour(s) with max {} is \n{}\n'.format(col_name, df2[df2[col_name] == df2[col_name].max()]))
  print('The hour(s) with min {} is \n{}\n'.format(col_name, df2[df2[col_name] == df2[col_name].min()]))

# %%
plot_points('PM2.5')
# Out:
# The hour(s) with max PM2.5 is
#        Day        Date      Time  PM2.5   PM10   NO2   NH3   SO2    CO  OZONE  \
# 15  Monday  01-08-2022  15:00:00  243.0  108.0  39.0  11.0  32.0  88.0   38.0
#
#      AQI
# 15  97.0
#
# The hour(s) with min PM2.5 is
#         Day        Date      Time  PM2.5  PM10   NO2   NH3   SO2     CO  \
# 1    Monday  01-08-2022  01:00:00    0.0  20.0  58.0  12.0  26.0   90.0
# 7    Monday  01-08-2022  07:00:00    0.0  72.0  67.0  12.0  24.0  102.0
# 28  Tuesday  02-08-2022  04:00:00    0.0  85.0  58.0   3.0  14.0   38.0
# 35  Tuesday  02-08-2022  11:00:00    0.0  38.0  62.0   2.0  13.0   35.0
# 42  Tuesday  02-08-2022  18:00:00    0.0   0.0  34.0   3.0  15.0   47.0
# 44  Tuesday  02-08-2022  20:00:00    0.0   0.0  53.0   3.0  12.0   42.0
# 45  Tuesday  02-08-2022  21:00:00    0.0  59.0  54.0   3.0  14.0   50.0
#
#     OZONE    AQI
# 1    38.0  105.0
# 7    38.0   98.0
# 28    4.0   51.0
# 35   21.0   56.0
# 42   40.0   58.0
# 44    4.0   60.0
# 45   11.0   60.0

# %%
plot_points('PM10')
# Out:
# The hour(s) with max PM10 is
#          Day        Date      Time  PM2.5   PM10   NO2   NH3   SO2    CO  \
# 707  Tuesday  08-30-2022  11:00:00   78.0  166.0  75.0  10.0  20.0  55.0
#
#      OZONE   AQI
# 707  109.0  92.0
#
# The hour(s) with min PM10 is
#         Day        Date      Time  PM2.5  PM10   NO2  NH3   SO2    CO  OZONE  \
# 42  Tuesday  02-08-2022  18:00:00    0.0   0.0  34.0  3.0  15.0  47.0   40.0
# 44  Tuesday  02-08-2022  20:00:00    0.0   0.0  53.0  3.0  12.0  42.0    4.0
#
#      AQI
# 42  58.0
# 44  60.0

# %%
plot_points('NO2')
# Out:
# The hour(s) with max NO2 is
#        Day        Date      Time  PM2.5  PM10   NO2   NH3   SO2     CO  OZONE  \
# 10  Monday  01-08-2022  10:00:00   47.0  64.0  92.0  11.0  11.0  109.0   37.0
#
#      AQI
# 10  94.0
#
# The hour(s) with min NO2 is
#           Day        Date      Time  PM2.5  PM10  NO2   NH3  SO2    CO  \
# 250  Thursday  11-08-2022  10:00:00   18.0  44.0  3.0  12.0  3.0  56.5
#
#         OZONE   AQI
# 250  9.652174  59.0

# %%
plot_points('NH3')
# Out:
# The hour(s) with max NH3 is
#         Day        Date      Time  PM2.5  PM10   NO2   NH3  SO2    CO  OZONE  \
# 280  Friday  12-08-2022  16:00:00   32.0  50.0  21.0  32.0  4.0  26.0    4.0
#
#       AQI
# 280  53.0
#
# The hour(s) with min NH3 is
#          Day        Date      Time  PM2.5   PM10   NO2  NH3   SO2    CO  \
# 24   Tuesday  02-08-2022  00:00:00   80.0  111.0  44.0  2.0  16.0  50.0
# 25   Tuesday  02-08-2022  01:00:00   40.0  101.0  45.0  2.0  15.0  42.0
# 26   Tuesday  02-08-2022  02:00:00   32.0   69.0  48.0  2.0  15.0  40.0
# 31   Tuesday  02-08-2022  07:00:00   78.0   55.0  40.0  2.0  16.0  35.0
# 32   Tuesday  02-08-2022  08:00:00   52.0   96.0  40.0  2.0  17.0  35.0
# ..       ...         ...       ...    ...    ...   ...  ...   ...   ...
# 319   Sunday  08-14-2022  07:00:00   15.0   34.0  39.0  2.0  15.0  27.0
# 320   Sunday  08-14-2022  08:00:00   10.0   22.0  40.0  2.0  14.0  25.0
# 321   Sunday  08-14-2022  09:00:00   10.0   34.0  42.0  2.0  14.0  25.0
# 322   Sunday  08-14-2022  10:00:00   13.0   46.0  44.0  2.0  13.0  25.0
# 323   Sunday  08-14-2022  11:00:00   15.0   41.0  47.0  2.0  13.0  30.0
#
#      OZONE   AQI
# 24    11.0  52.0
# 25     7.0  51.0
# 26     0.0  51.0
# 31     8.0  52.0
# 32    11.0  52.0
# ..     ...   ...
# 319   21.0  49.0
# 320   23.0  48.0
# 321   30.0  48.0
# 322   40.0  47.0
# 323   65.0  47.0
#
# [69 rows x 11 columns]

# %%
plot_points('SO2')
# Out:
# The hour(s) with max SO2 is
#           Day        Date      Time  PM2.5  PM10   NO2  NH3   SO2    CO  \
# 129  Saturday  06-08-2022  09:00:00   28.0  75.0  44.0  2.0  72.0  33.0
#
#      OZONE   AQI
# 129   12.0  78.0
#
# The hour(s) with min SO2 is
#         Day        Date      Time  PM2.5  PM10   NO2   NH3  SO2    CO  OZONE  \
# 5    Monday  01-08-2022  05:00:00   58.0  97.0  90.0  13.0  0.0  82.0   64.0
# 27  Tuesday  02-08-2022  03:00:00   33.0  83.0  54.0   3.0  0.0   0.0    4.0
#
#      AQI
# 5   97.0
# 27  51.0

# %%
plot_points('CO')
# Out:
# The hour(s) with max CO is
#        Day        Date      Time  PM2.5   PM10   NO2   NH3   SO2     CO  \
# 20  Monday  01-08-2022  20:00:00   60.0  101.0  48.0  12.0  29.0  118.0
# 21  Monday  01-08-2022  21:00:00   70.0  104.0  55.0  12.0  33.0  118.0
#
#     OZONE    AQI
# 20   46.0   99.0
# 21   52.0  102.0
#
# The hour(s) with min CO is
#         Day        Date      Time  PM2.5  PM10   NO2  NH3  SO2   CO  OZONE  \
# 27  Tuesday  02-08-2022  03:00:00   33.0  83.0  54.0  3.0  0.0  0.0    4.0
#
#      AQI
# 27  51.0

# %%
plot_points('OZONE')
# Out:
# The hour(s) with max OZONE is
#           Day        Date      Time  PM2.5   PM10   NO2   NH3   SO2    CO  \
# 593  Thursday  08-25-2022  17:00:00  100.0  141.0  60.0  10.0  14.0  43.0
#
#      OZONE    AQI
# 593  200.0  200.0
#
# The hour(s) with min OZONE is
#           Day        Date      Time  PM2.5  PM10   NO2  NH3   SO2    CO  \
# 26    Tuesday  02-08-2022  02:00:00   32.0  69.0  48.0  2.0  15.0  40.0
# 48  Wednesday  03-08-2022  00:00:00   30.0  59.0  49.0  2.0  14.0  40.0
#
#     OZONE   AQI
# 26    0.0  51.0
# 48    0.0  65.0

# %%
plot_points('AQI')
# Out:
# The hour(s) with max AQI is
#           Day        Date      Time  PM2.5   PM10   NO2   NH3   SO2    CO  \
# 593  Thursday  08-25-2022  17:00:00  100.0  141.0  60.0  10.0  14.0  43.0
#
#      OZONE    AQI
# 593  200.0  200.0
#
# The hour(s) with min AQI is
#            Day        Date      Time  PM2.5  PM10   NO2  NH3   SO2    CO  \
# 365    Tuesday  08-16-2022  05:00:00   26.0  32.0  14.0  9.0  21.0  12.0
# 381    Tuesday  08-16-2022  21:00:00    2.0  39.0  40.0  6.0  16.0  35.0
# 394  Wednesday  08-17-2022  10:00:00    8.0  45.0  51.0  4.0  13.0  40.0
# 395  Wednesday  08-17-2022  11:00:00   10.0  39.0  53.0  5.0  13.0  37.0
# 398  Wednesday  08-17-2022  14:00:00   27.0  68.0  47.0  3.0  15.0  28.0
#
#      OZONE   AQI
# 365   42.0  41.0
# 381   21.0  41.0
# 394   24.0  41.0
# 395   32.0  41.0
# 398   55.0  41.0

# %% [markdown]
# ## Daily data

# %% [markdown]
# Working on daily data

# %%
# making a new dataframe to fill with daily data instead of hourly data
df_daily = pd.DataFrame(columns=['DAY', 'DATE', 'PM2.5', 'PM10', 'NO2', 'NH3', 'SO2', 'CO', 'OZONE', 'AQI'])

# %% [markdown]
# Converting hourly data to daily data by finding the mean values of each day (i.e. mean value of 24 rows each)

# %%
# finding dates of each day in the dataset
dates = df2['Date'].unique()

# %%
dates, len(dates)
# Out:
# (array(['01-08-2022', '02-08-2022', '03-08-2022', '04-08-2022',
#         '05-08-2022', '06-08-2022', '07-08-2022', '08-08-2022',
#         '09-08-2022', '10-08-2022', '11-08-2022', '12-08-2022',
#         '08-13-2022', '08-14-2022', '08-15-2022', '08-16-2022',
#         '08-17-2022', '08-18-2022', '08-19-2022', '08-20-2022',
#         '08-21-2022', '08-22-2022', '08-23-2022', '08-24-2022',
#         '08-25-2022', '08-26-2022', '08-27-2022', '08-28-2022',
#         '08-29-2022', '08-30-2022', '08-31-2022'], dtype=object), 31)

# %%
days_list = []

# %%
# making a list of each day occured in the dataset
count = 0
for i in range (0,len(df2),24):
  count = count+1
  days_list.append(df2.iloc[0+i, [0]].values)
print('The number of days are: {}'.format(count))
# Out:
# The number of days are: 31

# %%
days_list
# Out:
# [array(['Monday'], dtype=object),
#  array(['Tuesday'], dtype=object),
#  array(['Wednesday'], dtype=object),
#  array(['Thursday'], dtype=object),
#  array(['Friday'], dtype=object),
#  array(['Saturday'], dtype=object),
#  array(['Sunday'], dtype=object),
#  array(['Sunday'], dtype=object),
#  array(['Tuesday'], dtype=object),
#  array(['Wednesday'], dtype=object),
#  array(['Thursday'], dtype=object),
#  array(['Friday'], dtype=object),
#  array(['Friday'], dtype=object),
#  array(['Sunday'], dtype=object),
#  array(['Monday'], dtype=object),
#  array(['Tuesday'], dtype=object),
#  array(['Wednesday'], dtype=object),
#  array(['Thursday'], dtype=object),
#  array(['Friday'], dtype=object),
#  array(['Saturday'], dtype=object),
#  array(['Sunday'], dtype=object),
#  array(['Monday'], dtype=object),
#  array(['Tuesday'], dtype=object),
#  array(['Wednesday'], dtype=object),
#  array(['Thursday'], dtype=object),
#  array(['Friday'], dtype=object),
#  array(['Saturday'], dtype=object),
#  array(['Sunday'], dtype=object),
#  array(['Monday'], dtype=object),
#  array(['Tuesday'], dtype=object),
#  array(['Wednesday'], dtype=object)]

# %%
# converting the list to a numpy array
days_array = np.asarray(days_list)

# %%
days_array
# Out:
# array([['Monday'],
#        ['Tuesday'],
#        ['Wednesday'],
#        ['Thursday'],
#        ['Friday'],
#        ['Saturday'],
#        ['Sunday'],
#        ['Sunday'],
#        ['Tuesday'],
#        ['Wednesday'],
#        ['Thursday'],
#        ['Friday'],
#        ['Friday'],
#        ['Sunday'],
#        ['Monday'],
#        ['Tuesday'],
#        ['Wednesday'],
#        ['Thursday'],
#        ['Friday'],
#        ['Saturday'],
#        ['Sunday'],
#        ['Monday'],
#        ['Tuesday'],
#        ['Wednesday'],
#        ['Thursday'],
#        ['Friday'],
#        ['Saturday'],
#        ['Sunday'],
#        ['Monday'],
#        ['Tuesday'],
#        ['Wednesday']], dtype=object)

# %%
# Converting the 2D array to 1D array
days_array.flatten()
# Out:
# array(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday',
#        'Sunday', 'Sunday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday',
#        'Friday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday', 'Thursday',
#        'Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday', 'Wednesday',
#        'Thursday', 'Friday', 'Saturday', 'Sunday', 'Monday', 'Tuesday',
#        'Wednesday'], dtype=object)

# %%
df_daily['DATE'] = dates

# %%
df_daily['DAY'] = days_array

# %%
# function to fill the pollutants columns by finding the mean of each day
def fill_df(cname,cval):
  lst = []
  for i in range (0,len(df2),24):
    lst.append(df2.iloc[0+i:24+i , [cval]].mean().values)

  arr = np.asarray(lst)

  arr.flatten()
  df_daily[cname] = arr

# %%
fill_df('PM2.5', 3)
fill_df('PM10', 4)
fill_df('NO2', 5)
fill_df('NH3', 6)
fill_df('SO2', 7)
fill_df('CO', 8)
fill_df('OZONE', 9)
fill_df('AQI', 10)

# %% [markdown]
# Filling the newly obtained daily values in the new dataframe

# %%
df_daily.head()
# Out:
#          DAY        DATE      PM2.5       PM10        NO2        NH3  \
# 0     Monday  01-08-2022  70.166667  87.708333  58.812500  12.333333
# 1    Tuesday  02-08-2022  38.666667  74.833333  46.937500   2.541667
# 2  Wednesday  03-08-2022  27.437500  53.395833  49.083333   2.500000
# 3   Thursday  04-08-2022  32.520833  61.812500  46.937500   2.541667
# 4     Friday  05-08-2022  57.916667  82.062500  54.500000   3.416667
#
#          SO2         CO      OZONE        AQI
# 0  18.375000  94.541667  45.500000  99.416667
# 1  14.437500  39.187500  16.729167  55.375000
# 2  15.708333  26.437500  11.875000  56.250000
# 3  15.166667  40.687500  16.875000  75.541667
# 4  11.270833  25.354167  15.833333  87.916667

# %%
# function to print the value of the column on top of it
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], round(y[i],2), ha = 'center')

# %%
# function to plot the bar graphs of each pollutant
def plot_graph(name):
  fig = plt.figure(figsize =(30, 10))
  plt.xlabel('Dates')
  plt.ylabel(name)
  plt.xticks(rotation = 60)
  addlabels(df_daily['DATE'], df_daily[name])
  plt.bar(df_daily['DATE'], df_daily[name])

  print('The date with max {} is \n{}\n'.format(name, df_daily[df_daily[name] == df_daily[name].max()]))
  print('The date with min {} is \n{}\n'.format(name, df_daily[df_daily[name] == df_daily[name].min()]))

# %%
plot_graph('PM2.5')
# Out:
# The date with max PM2.5 is
#       DAY        DATE      PM2.5       PM10      NO2        NH3     SO2  \
# 0  Monday  01-08-2022  70.166667  87.708333  58.8125  12.333333  18.375
#
#           CO  OZONE        AQI
# 0  94.541667   45.5  99.416667
#
# The date with min PM2.5 is
#           DAY        DATE      PM2.5       PM10        NO2   NH3        SO2  \
# 16  Wednesday  08-17-2022  14.458333  41.229167  48.666667  4.25  13.395833
#
#            CO      OZONE        AQI
# 16  34.958333  33.333333  44.791667

# %%
plot_graph('PM10')
# Out:
# The date with max PM10 is
#        DAY        DATE    PM2.5      PM10        NO2        NH3        SO2  \
# 28  Monday  08-29-2022  46.4375  118.0625  58.520833  10.458333  14.770833
#
#            CO    OZONE         AQI
# 28  32.041667  55.1875  116.708333
#
# The date with min PM10 is
#           DAY        DATE      PM2.5       PM10        NO2   NH3        SO2  \
# 16  Wednesday  08-17-2022  14.458333  41.229167  48.666667  4.25  13.395833
#
#            CO      OZONE        AQI
# 16  34.958333  33.333333  44.791667

# %%
plot_graph('NO2')
# Out:
# The date with max NO2 is
#         DAY        DATE    PM2.5       PM10    NO2   NH3    SO2       CO  \
# 29  Tuesday  08-30-2022  49.8125  89.583333  66.25  10.5  14.75  40.1875
#
#         OZONE         AQI
# 29  49.479167  105.083333
#
# The date with min NO2 is
#          DAY        DATE  PM2.5   PM10     NO2        NH3       SO2  \
# 10  Thursday  11-08-2022  20.75  49.25  10.375  10.229167  4.583333
#
#            CO     OZONE        AQI
# 10  54.041667  9.604167  58.541667

# %%
plot_graph('NH3')
# Out:
# The date with max NH3 is
#        DAY        DATE      PM2.5     PM10        NO2        NH3      SO2  \
# 20  Sunday  08-21-2022  45.041667  91.0625  49.020833  13.833333  38.5625
#
#            CO  OZONE        AQI
# 20  36.645833   16.0  76.708333
#
# The date with min NH3 is
#          DAY        DATE      PM2.5     PM10     NO2       NH3      SO2  \
# 9  Wednesday  10-08-2022  37.291667  64.6875  49.125  2.395833  13.4375
#
#           CO      OZONE    AQI
# 9  41.770833  36.604167  53.25

# %%
plot_graph('SO2')
# Out:
# The date with max SO2 is
#        DAY        DATE      PM2.5     PM10        NO2        NH3      SO2  \
# 20  Sunday  08-21-2022  45.041667  91.0625  49.020833  13.833333  38.5625
#
#            CO  OZONE        AQI
# 20  36.645833   16.0  76.708333
#
# The date with min SO2 is
#          DAY        DATE  PM2.5   PM10     NO2        NH3       SO2  \
# 10  Thursday  11-08-2022  20.75  49.25  10.375  10.229167  4.583333
#
#            CO     OZONE        AQI
# 10  54.041667  9.604167  58.541667

# %%
plot_graph('CO')
# Out:
# The date with max CO is
#       DAY        DATE      PM2.5       PM10      NO2        NH3     SO2  \
# 0  Monday  01-08-2022  70.166667  87.708333  58.8125  12.333333  18.375
#
#           CO  OZONE        AQI
# 0  94.541667   45.5  99.416667
#
# The date with min CO is
#       DAY        DATE      PM2.5     PM10   NO2       NH3        SO2  \
# 4  Friday  05-08-2022  57.916667  82.0625  54.5  3.416667  11.270833
#
#           CO      OZONE        AQI
# 4  25.354167  15.833333  87.916667

# %%
plot_graph('OZONE')
# Out:
# The date with max OZONE is
#          DAY        DATE      PM2.5    PM10        NO2        NH3      SO2  \
# 24  Thursday  08-25-2022  47.520833  79.125  58.916667  10.666667  13.8125
#
#            CO  OZONE        AQI
# 24  36.854167   58.0  82.666667
#
# The date with min OZONE is
#        DAY        DATE  PM2.5       PM10        NO2        NH3        SO2  \
# 11  Friday  12-08-2022   36.5  55.791667  24.958333  11.541667  14.104167
#
#            CO     OZONE        AQI
# 11  36.833333  7.916667  54.833333

# %%
plot_graph('AQI')
# Out:
# The date with max AQI is
#        DAY        DATE    PM2.5      PM10        NO2        NH3        SO2  \
# 28  Monday  08-29-2022  46.4375  118.0625  58.520833  10.458333  14.770833
#
#            CO    OZONE         AQI
# 28  32.041667  55.1875  116.708333
#
# The date with min AQI is
#         DAY        DATE      PM2.5  PM10        NO2       NH3   SO2  \
# 15  Tuesday  08-16-2022  25.020833  44.5  25.791667  9.041667  17.5
#
#            CO      OZONE    AQI
# 15  29.416667  35.291667  43.25

# %%
df_daily.to_csv(r'/content/drive/MyDrive/MiniProject/chandnichowk_daily.csv', index = 'False')
